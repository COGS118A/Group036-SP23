# %% [markdown]
# # Neural Networks vs KNN vs XGBoost

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyarrow.feather as feather
import torch
from tqdm.notebook import tqdm
tqdm.pandas()
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, KFold
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# First, we organize all our data. All data has been preprocessed...

# %%
# First pull in all our data

df_lyrics = pd.read_feather('data_lyrics1_training').reset_index(drop=True).iloc[:550000]

# %%
df_lyrics.shape
# Out:
# (550000, 512)

# %%
df_titles = pd.read_feather('data_titles_training').reset_index(drop=True).iloc[:550000]

# %%
df_else = pd.read_feather('data_else_training').reset_index(drop=True).iloc[:550000]
df_artists = df_else['artist']
df_tags = df_else[['tag0', 'tag1', 'tag2', 'tag3', 'tag4', 'tag5']]
df_age = df_else['age']
df_views = df_else['encoded_views']

# %%
df_views = df_views-1

# %%
df_views.value_counts()
# Out:
# 4     79052
# 5     76303
# 3     71985
# 6     68080
# 7     55898
# 2     47019
# 8     40458
# 9     26474
# 1     25805
# 0     20668
# 10    16880
# 11    10054
# 12     5733
# 13     3025
# 14     1488
# 15      683
# 16      264
# 17      100
# 18       28
# 19        3
# Name: encoded_views, dtype: int64

# %%
dfs = [df_lyrics, df_titles, df_artists, df_age, df_tags, df_views]
data = pd.concat(dfs, axis=1)

# %%
train_idx, test_idx = train_test_split(list(range(0, len(df_views))), test_size=0.2, random_state=42)

# %%
data.drop(["encoded_views"], axis=1, inplace=True)

# %%
#xgboost classifier using random search and the gpu
from tqdm.notebook import tqdm
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score

# A parameter grid for XGBoost
params = {
        'min_child_weight': [1, 5, 10], 
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

xgb = xgb.XGBClassifier(learning_rate=0.02, n_estimators=600, objective='multi:softmax', nthread=1, tree_method = 'gpu_hist', verbosity=3)


# with tqdm(total=random_search.n_iter * len(data)) as pbar:
#     def update_pbar(iteration, of, candidate, cv_scores):
#         pbar.update()

# random_search.fit(data, df_views, callback=update_pbar)

# %%
folds = 3
param_comb = 5

kf = KFold(n_splits=folds, shuffle = True, random_state = 42)


random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=param_comb, scoring='accuracy', n_jobs=1, cv=kf.split(data.iloc[train_idx], df_views.iloc[train_idx]), verbose=3, random_state=42 )

# %%
random_search.fit(data.iloc[train_idx], df_views.iloc[train_idx])
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [16:09:46] ======== Monitor (0): HostSketchContainer ========
# [16:09:46] AllReduce: 0.043214s, 1 calls @ 43214us
#
# [16:09:46] MakeCuts: 0.044796s, 1 calls @ 44796us
#
# [16:09:46] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:09:46] ======== Monitor (0):  ========
# [16:09:46] InitCompressedData: 0.032938s, 1 calls @ 32938us
#
# [16:12:48] ======== Monitor (0): Learner ========
# [16:12:48] Configure: 0.000929s, 1 calls @ 929us
#
# [16:12:48] EvalOneIter: 0.005959s, 600 calls @ 5959us
#
# [16:12:48] GetGradient: 0.960144s, 600 calls @ 960144us
#
# [16:12:48] PredictRaw: 0.003309s, 600 calls @ 3309us
#
# [16:12:48] UpdateOneIter: 181.088s, 600 calls @ 181088214us
#
# [16:12:48] ======== Monitor (0): GBTree ========
# [16:12:48] BoostNewTrees: 180.11s, 600 calls @ 180110261us
#
# [16:12:48] CommitModel: 0.000722s, 600 calls @ 722us
#
# [16:12:48] ======== Device 0 Memory Allocations:  ========
# [16:12:48] Peak memory usage: 1327MiB
# [16:12:48] Number of allocations: 957211
# [16:12:48] ======== Monitor (0): updater_gpu_hist ========
# [16:12:48] InitData: 0.076998s, 12000 calls @ 76998us
#
# [16:12:48] InitDataOnce: 0.075958s, 1 calls @ 75958us
#
# [16:12:48] Update: 177.081s, 12000 calls @ 177080579us
#
# [16:12:48] UpdatePredictionCache: 2.34679s, 12000 calls @ 2346786us
#
# [16:12:48] ======== Monitor (0): gradient_based_sampler ========
# [16:12:48] Sample: 0.666269s, 12000 calls @ 666269us
#
# [16:12:48] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:12:48] AllReduce: 0.008687s, 43718 calls @ 8687us
#
# [16:12:48] BuildHist: 0.82285s, 42004 calls @ 822850us
#
# [16:12:48] EvaluateSplits: 72.3858s, 42004 calls @ 72385756us
#
# [16:12:48] FinalisePosition: 0.63629s, 12000 calls @ 636290us
#
# [16:12:48] InitRoot: 93.2118s, 12000 calls @ 93211767us
#
# [16:12:48] Reset: 3.24881s, 12000 calls @ 3248814us
#
# [16:12:48] UpdatePosition: 6.43515s, 42004 calls @ 6435146us
#
# [16:12:48] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 1/3] END colsample_bytree=0.6, gamma=1.5, max_depth=4, min_child_weight=10, subsample=0.8;, score=0.259 total time= 3.5min
# [16:13:17] ======== Monitor (0): HostSketchContainer ========
# [16:13:17] AllReduce: 0.039527s, 1 calls @ 39527us
#
# [16:13:17] MakeCuts: 0.040595s, 1 calls @ 40595us
#
# [16:13:18] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:13:18] ======== Monitor (0):  ========
# [16:13:18] InitCompressedData: 0.047693s, 1 calls @ 47693us
#
# [16:16:11] ======== Monitor (0): Learner ========
# [16:16:11] Configure: 0.00097s, 1 calls @ 970us
#
# [16:16:11] EvalOneIter: 0.005181s, 600 calls @ 5181us
#
# [16:16:11] GetGradient: 0.897187s, 600 calls @ 897187us
#
# [16:16:11] PredictRaw: 0.006124s, 600 calls @ 6124us
#
# [16:16:11] UpdateOneIter: 172.101s, 600 calls @ 172101081us
#
# [16:16:11] ======== Monitor (0): GBTree ========
# [16:16:11] BoostNewTrees: 171.185s, 600 calls @ 171185253us
#
# [16:16:11] CommitModel: 0.000611s, 600 calls @ 611us
#
# [16:16:11] ======== Device 0 Memory Allocations:  ========
# [16:16:11] Peak memory usage: 1669MiB
# [16:16:11] Number of allocations: 1402582
# [16:16:11] ======== Monitor (0): updater_gpu_hist ========
# [16:16:11] InitData: 0.131091s, 12000 calls @ 131091us
#
# [16:16:11] InitDataOnce: 0.130057s, 1 calls @ 130057us
#
# [16:16:11] Update: 168.304s, 12000 calls @ 168303673us
#
# [16:16:11] UpdatePredictionCache: 2.23756s, 12000 calls @ 2237559us
#
# [16:16:11] ======== Monitor (0): gradient_based_sampler ========
# [16:16:11] Sample: 0.646938s, 12000 calls @ 646938us
#
# [16:16:11] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:16:11] AllReduce: 0.008734s, 43752 calls @ 8734us
#
# [16:16:11] BuildHist: 0.819548s, 42085 calls @ 819548us
#
# [16:16:11] EvaluateSplits: 69.1956s, 42085 calls @ 69195586us
#
# [16:16:11] FinalisePosition: 0.605681s, 12000 calls @ 605681us
#
# [16:16:11] InitRoot: 87.9383s, 12000 calls @ 87938261us
#
# [16:16:11] Reset: 3.1768s, 12000 calls @ 3176798us
#
# [16:16:11] UpdatePosition: 6.19397s, 42085 calls @ 6193973us
#
# [16:16:11] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 2/3] END colsample_bytree=0.6, gamma=1.5, max_depth=4, min_child_weight=10, subsample=0.8;, score=0.259 total time= 3.3min
# [16:16:39] ======== Monitor (0): HostSketchContainer ========
# [16:16:39] AllReduce: 0.039986s, 1 calls @ 39986us
#
# [16:16:39] MakeCuts: 0.041213s, 1 calls @ 41213us
#
# [16:16:39] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:16:39] ======== Monitor (0):  ========
# [16:16:39] InitCompressedData: 0.056515s, 1 calls @ 56515us
#
# [16:19:37] ======== Monitor (0): Learner ========
# [16:19:37] Configure: 0.001325s, 1 calls @ 1325us
#
# [16:19:37] EvalOneIter: 0.005787s, 600 calls @ 5787us
#
# [16:19:37] GetGradient: 0.956091s, 600 calls @ 956091us
#
# [16:19:37] PredictRaw: 0.004704s, 600 calls @ 4704us
#
# [16:19:37] UpdateOneIter: 176.49s, 600 calls @ 176489553us
#
# [16:19:37] ======== Monitor (0): GBTree ========
# [16:19:37] BoostNewTrees: 175.515s, 600 calls @ 175514967us
#
# [16:19:37] CommitModel: 0.000683s, 600 calls @ 683us
#
# [16:19:37] ======== Device 0 Memory Allocations:  ========
# [16:19:37] Peak memory usage: 2012MiB
# [16:19:37] Number of allocations: 1846524
# [16:19:37] ======== Monitor (0): updater_gpu_hist ========
# [16:19:37] InitData: 0.22206s, 12000 calls @ 222060us
#
# [16:19:37] InitDataOnce: 0.221035s, 1 calls @ 221035us
#
# [16:19:37] Update: 172.52s, 12000 calls @ 172520040us
#
# [16:19:37] UpdatePredictionCache: 2.32103s, 12000 calls @ 2321032us
#
# [16:19:37] ======== Monitor (0): gradient_based_sampler ========
# [16:19:37] Sample: 0.660295s, 12000 calls @ 660295us
#
# [16:19:37] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:19:37] AllReduce: 0.008982s, 43582 calls @ 8982us
#
# [16:19:37] BuildHist: 0.825234s, 41780 calls @ 825234us
#
# [16:19:37] EvaluateSplits: 70.1894s, 41780 calls @ 70189378us
#
# [16:19:37] FinalisePosition: 0.623932s, 12000 calls @ 623932us
#
# [16:19:37] InitRoot: 90.8227s, 12000 calls @ 90822715us
#
# [16:19:37] Reset: 3.22969s, 12000 calls @ 3229690us
#
# [16:19:37] UpdatePosition: 6.35365s, 41780 calls @ 6353647us
#
# [16:19:37] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 3/3] END colsample_bytree=0.6, gamma=1.5, max_depth=4, min_child_weight=10, subsample=0.8;, score=0.259 total time= 3.5min
# [16:20:07] ======== Monitor (0): HostSketchContainer ========
# [16:20:07] AllReduce: 0.039769s, 1 calls @ 39769us
#
# [16:20:07] MakeCuts: 0.041125s, 1 calls @ 41125us
#
# [16:20:08] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:20:08] ======== Monitor (0):  ========
# [16:20:08] InitCompressedData: 0.050206s, 1 calls @ 50206us
#
# [16:22:47] ======== Monitor (0): Learner ========
# [16:22:47] Configure: 0.001049s, 1 calls @ 1049us
#
# [16:22:47] EvalOneIter: 0.006088s, 600 calls @ 6088us
#
# [16:22:47] GetGradient: 0.971347s, 600 calls @ 971347us
#
# [16:22:47] PredictRaw: 0.007374s, 600 calls @ 7374us
#
# [16:22:47] UpdateOneIter: 158.746s, 600 calls @ 158745518us
#
# [16:22:47] ======== Monitor (0): GBTree ========
# [16:22:47] BoostNewTrees: 157.752s, 600 calls @ 157752443us
#
# [16:22:47] CommitModel: 0.000749s, 600 calls @ 749us
#
# [16:22:47] ======== Device 0 Memory Allocations:  ========
# [16:22:47] Peak memory usage: 2354MiB
# [16:22:47] Number of allocations: 2208967
# [16:22:47] ======== Monitor (0): updater_gpu_hist ========
# [16:22:47] InitData: 0.220732s, 12000 calls @ 220732us
#
# [16:22:47] InitDataOnce: 0.219717s, 1 calls @ 219717us
#
# [16:22:47] Update: 154.585s, 12000 calls @ 154584826us
#
# [16:22:47] UpdatePredictionCache: 2.48419s, 12000 calls @ 2484186us
#
# [16:22:47] ======== Monitor (0): gradient_based_sampler ========
# [16:22:47] Sample: 0.00357s, 12000 calls @ 3570us
#
# [16:22:47] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:22:47] AllReduce: 0.00668s, 33390 calls @ 6680us
#
# [16:22:47] BuildHist: 0.411849s, 32078 calls @ 411849us
#
# [16:22:47] EvaluateSplits: 52.6374s, 32078 calls @ 52637396us
#
# [16:22:47] FinalisePosition: 0.611028s, 12000 calls @ 611028us
#
# [16:22:47] InitRoot: 93.5499s, 12000 calls @ 93549940us
#
# [16:22:47] Reset: 2.6338s, 12000 calls @ 2633799us
#
# [16:22:47] UpdatePosition: 4.33697s, 32078 calls @ 4336969us
#
# [16:22:47] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 1/3] END colsample_bytree=0.8, gamma=2, max_depth=3, min_child_weight=1, subsample=1.0;, score=0.257 total time= 3.0min
# [16:23:10] ======== Monitor (0): HostSketchContainer ========
# [16:23:10] AllReduce: 0.040192s, 1 calls @ 40192us
#
# [16:23:10] MakeCuts: 0.041497s, 1 calls @ 41497us
#
# [16:23:10] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:23:10] ======== Monitor (0):  ========
# [16:23:10] InitCompressedData: 0.067022s, 1 calls @ 67022us
#
# [16:25:39] ======== Monitor (0): Learner ========
# [16:25:39] Configure: 0.001105s, 1 calls @ 1105us
#
# [16:25:39] EvalOneIter: 0.005037s, 600 calls @ 5037us
#
# [16:25:39] GetGradient: 0.919093s, 600 calls @ 919093us
#
# [16:25:39] PredictRaw: 0.004661s, 600 calls @ 4661us
#
# [16:25:39] UpdateOneIter: 148.015s, 600 calls @ 148014507us
#
# [16:25:39] ======== Monitor (0): GBTree ========
# [16:25:39] BoostNewTrees: 147.078s, 600 calls @ 147078456us
#
# [16:25:39] CommitModel: 0.000692s, 600 calls @ 692us
#
# [16:25:39] ======== Device 0 Memory Allocations:  ========
# [16:25:39] Peak memory usage: 2697MiB
# [16:25:39] Number of allocations: 2575730
# [16:25:39] ======== Monitor (0): updater_gpu_hist ========
# [16:25:39] InitData: 0.162557s, 12000 calls @ 162557us
#
# [16:25:39] InitDataOnce: 0.161515s, 1 calls @ 161515us
#
# [16:25:39] Update: 144.187s, 12000 calls @ 144186513us
#
# [16:25:39] UpdatePredictionCache: 2.27862s, 12000 calls @ 2278620us
#
# [16:25:39] ======== Monitor (0): gradient_based_sampler ========
# [16:25:39] Sample: 0.002995s, 12000 calls @ 2995us
#
# [16:25:39] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:25:39] AllReduce: 0.006328s, 33891 calls @ 6328us
#
# [16:25:39] BuildHist: 0.411725s, 32598 calls @ 411725us
#
# [16:25:39] EvaluateSplits: 49.3833s, 32598 calls @ 49383273us
#
# [16:25:39] FinalisePosition: 0.566598s, 12000 calls @ 566598us
#
# [16:25:39] InitRoot: 86.8086s, 12000 calls @ 86808559us
#
# [16:25:39] Reset: 2.50047s, 12000 calls @ 2500471us
#
# [16:25:39] UpdatePosition: 4.19545s, 32598 calls @ 4195449us
#
# [16:25:39] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 2/3] END colsample_bytree=0.8, gamma=2, max_depth=3, min_child_weight=1, subsample=1.0;, score=0.255 total time= 2.9min
# [16:26:01] ======== Monitor (0): HostSketchContainer ========
# [16:26:01] AllReduce: 0.040538s, 1 calls @ 40538us
#
# [16:26:01] MakeCuts: 0.042163s, 1 calls @ 42163us
#
# [16:26:01] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:26:02] ======== Monitor (0):  ========
# [16:26:02] InitCompressedData: 0.045295s, 1 calls @ 45295us
#
# [16:28:42] ======== Monitor (0): Learner ========
# [16:28:42] Configure: 0.0008s, 1 calls @ 800us
#
# [16:28:42] EvalOneIter: 0.005981s, 600 calls @ 5981us
#
# [16:28:42] GetGradient: 0.961665s, 600 calls @ 961665us
#
# [16:28:42] PredictRaw: 0.003885s, 600 calls @ 3885us
#
# [16:28:42] UpdateOneIter: 159.128s, 600 calls @ 159127561us
#
# [16:28:42] ======== Monitor (0): GBTree ========
# [16:28:42] BoostNewTrees: 158.148s, 600 calls @ 158147868us
#
# [16:28:42] CommitModel: 0.000723s, 600 calls @ 723us
#
# [16:28:42] ======== Device 0 Memory Allocations:  ========
# [16:28:42] Peak memory usage: 3040MiB
# [16:28:42] Number of allocations: 2937252
# [16:28:42] ======== Monitor (0): updater_gpu_hist ========
# [16:28:42] InitData: 0.161885s, 12000 calls @ 161885us
#
# [16:28:42] InitDataOnce: 0.16087s, 1 calls @ 160870us
#
# [16:28:42] Update: 155.027s, 12000 calls @ 155026680us
#
# [16:28:42] UpdatePredictionCache: 2.42668s, 12000 calls @ 2426681us
#
# [16:28:42] ======== Monitor (0): gradient_based_sampler ========
# [16:28:42] Sample: 0.003602s, 12000 calls @ 3602us
#
# [16:28:42] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:28:42] AllReduce: 0.006677s, 33276 calls @ 6677us
#
# [16:28:42] BuildHist: 0.417986s, 31859 calls @ 417986us
#
# [16:28:42] EvaluateSplits: 52.4823s, 31859 calls @ 52482318us
#
# [16:28:42] FinalisePosition: 0.641313s, 12000 calls @ 641313us
#
# [16:28:42] InitRoot: 94.1417s, 12000 calls @ 94141680us
#
# [16:28:42] Reset: 2.66149s, 12000 calls @ 2661494us
#
# [16:28:42] UpdatePosition: 4.33667s, 31859 calls @ 4336670us
#
# [16:28:42] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 3/3] END colsample_bytree=0.8, gamma=2, max_depth=3, min_child_weight=1, subsample=1.0;, score=0.256 total time= 3.0min
# [16:29:04] ======== Monitor (0): HostSketchContainer ========
# [16:29:04] AllReduce: 0.04291s, 1 calls @ 42910us
#
# [16:29:04] MakeCuts: 0.044123s, 1 calls @ 44123us
#
# [16:29:04] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:29:04] ======== Monitor (0):  ========
# [16:29:04] InitCompressedData: 0.059072s, 1 calls @ 59072us
#
# [16:31:43] ======== Monitor (0): Learner ========
# [16:31:43] Configure: 0.001235s, 1 calls @ 1235us
#
# [16:31:43] EvalOneIter: 0.005905s, 600 calls @ 5905us
#
# [16:31:43] GetGradient: 0.96771s, 600 calls @ 967710us
#
# [16:31:43] PredictRaw: 0.004419s, 600 calls @ 4419us
#
# [16:31:43] UpdateOneIter: 158.008s, 600 calls @ 158007734us
#
# [16:31:43] ======== Monitor (0): GBTree ========
# [16:31:43] BoostNewTrees: 157.019s, 600 calls @ 157018530us
#
# [16:31:43] CommitModel: 0.000633s, 600 calls @ 633us
#
# [16:31:43] ======== Device 0 Memory Allocations:  ========
# [16:31:43] Peak memory usage: 3382MiB
# [16:31:43] Number of allocations: 3268416
# [16:31:43] ======== Monitor (0): updater_gpu_hist ========
# [16:31:43] InitData: 0.20016s, 12000 calls @ 200160us
#
# [16:31:43] InitDataOnce: 0.199183s, 1 calls @ 199183us
#
# [16:31:43] Update: 154.005s, 12000 calls @ 154005135us
#
# [16:31:43] UpdatePredictionCache: 2.3162s, 12000 calls @ 2316200us
#
# [16:31:43] ======== Monitor (0): gradient_based_sampler ========
# [16:31:43] Sample: 0.659525s, 12000 calls @ 659525us
#
# [16:31:43] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:31:43] AllReduce: 0.00634s, 32530 calls @ 6340us
#
# [16:31:43] BuildHist: 0.396483s, 30628 calls @ 396483us
#
# [16:31:43] EvaluateSplits: 51.5458s, 30628 calls @ 51545827us
#
# [16:31:43] FinalisePosition: 0.645772s, 12000 calls @ 645772us
#
# [16:31:43] InitRoot: 93.8213s, 12000 calls @ 93821294us
#
# [16:31:43] Reset: 3.00864s, 12000 calls @ 3008642us
#
# [16:31:43] UpdatePosition: 4.20881s, 30628 calls @ 4208806us
#
# [16:31:43] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 1/3] END colsample_bytree=1.0, gamma=5, max_depth=3, min_child_weight=10, subsample=0.8;, score=0.257 total time= 3.0min
# [16:32:05] ======== Monitor (0): HostSketchContainer ========
# [16:32:05] AllReduce: 0.043801s, 1 calls @ 43801us
#
# [16:32:05] MakeCuts: 0.045s, 1 calls @ 45000us
#
# [16:32:05] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:32:05] ======== Monitor (0):  ========
# [16:32:05] InitCompressedData: 0.048178s, 1 calls @ 48178us
#
# [16:34:43] ======== Monitor (0): Learner ========
# [16:34:43] Configure: 0.001021s, 1 calls @ 1021us
#
# [16:34:43] EvalOneIter: 0.0059s, 600 calls @ 5900us
#
# [16:34:43] GetGradient: 0.96621s, 600 calls @ 966210us
#
# [16:34:43] PredictRaw: 0.006099s, 600 calls @ 6099us
#
# [16:34:43] UpdateOneIter: 157.395s, 600 calls @ 157394807us
#
# [16:34:43] ======== Monitor (0): GBTree ========
# [16:34:43] BoostNewTrees: 156.408s, 600 calls @ 156407949us
#
# [16:34:43] CommitModel: 0.001108s, 600 calls @ 1108us
#
# [16:34:43] ======== Device 0 Memory Allocations:  ========
# [16:34:43] Peak memory usage: 3725MiB
# [16:34:43] Number of allocations: 3600229
# [16:34:43] ======== Monitor (0): updater_gpu_hist ========
# [16:34:43] InitData: 0.159875s, 12000 calls @ 159875us
#
# [16:34:43] InitDataOnce: 0.158896s, 1 calls @ 158896us
#
# [16:34:43] Update: 153.372s, 12000 calls @ 153371786us
#
# [16:34:43] UpdatePredictionCache: 2.3469s, 12000 calls @ 2346896us
#
# [16:34:43] ======== Monitor (0): gradient_based_sampler ========
# [16:34:43] Sample: 0.659541s, 12000 calls @ 659541us
#
# [16:34:43] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:34:43] AllReduce: 0.006315s, 32606 calls @ 6315us
#
# [16:34:43] BuildHist: 0.391745s, 30697 calls @ 391745us
#
# [16:34:43] EvaluateSplits: 51.3066s, 30697 calls @ 51306606us
#
# [16:34:43] FinalisePosition: 0.640504s, 12000 calls @ 640504us
#
# [16:34:43] InitRoot: 93.4568s, 12000 calls @ 93456754us
#
# [16:34:43] Reset: 3.01862s, 12000 calls @ 3018621us
#
# [16:34:43] UpdatePosition: 4.21482s, 30697 calls @ 4214818us
#
# [16:34:43] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 2/3] END colsample_bytree=1.0, gamma=5, max_depth=3, min_child_weight=10, subsample=0.8;, score=0.256 total time= 3.0min
# [16:35:05] ======== Monitor (0): HostSketchContainer ========
# [16:35:05] AllReduce: 0.041786s, 1 calls @ 41786us
#
# [16:35:05] MakeCuts: 0.043134s, 1 calls @ 43134us
#
# [16:35:05] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:35:05] ======== Monitor (0):  ========
# [16:35:05] InitCompressedData: 0.04734s, 1 calls @ 47340us
#
# [16:37:37] ======== Monitor (0): Learner ========
# [16:37:37] Configure: 0.000929s, 1 calls @ 929us
#
# [16:37:37] EvalOneIter: 0.005252s, 600 calls @ 5252us
#
# [16:37:37] GetGradient: 0.951627s, 600 calls @ 951627us
#
# [16:37:37] PredictRaw: 0.006733s, 600 calls @ 6733us
#
# [16:37:37] UpdateOneIter: 150.653s, 600 calls @ 150652777us
#
# [16:37:37] ======== Monitor (0): GBTree ========
# [16:37:37] BoostNewTrees: 149.682s, 600 calls @ 149681690us
#
# [16:37:37] CommitModel: 0.000557s, 600 calls @ 557us
#
# [16:37:37] ======== Device 0 Memory Allocations:  ========
# [16:37:37] Peak memory usage: 4067MiB
# [16:37:37] Number of allocations: 3930796
# [16:37:37] ======== Monitor (0): updater_gpu_hist ========
# [16:37:37] InitData: 0.110066s, 12000 calls @ 110066us
#
# [16:37:37] InitDataOnce: 0.10911s, 1 calls @ 109110us
#
# [16:37:37] Update: 146.788s, 12000 calls @ 146788469us
#
# [16:37:37] UpdatePredictionCache: 2.21027s, 12000 calls @ 2210271us
#
# [16:37:37] ======== Monitor (0): gradient_based_sampler ========
# [16:37:37] Sample: 0.648025s, 12000 calls @ 648025us
#
# [16:37:37] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:37:37] AllReduce: 0.006092s, 32457 calls @ 6092us
#
# [16:37:37] BuildHist: 0.374136s, 30459 calls @ 374136us
#
# [16:37:37] EvaluateSplits: 49.0593s, 30459 calls @ 49059305us
#
# [16:37:37] FinalisePosition: 0.602536s, 12000 calls @ 602536us
#
# [16:37:37] InitRoot: 89.6314s, 12000 calls @ 89631392us
#
# [16:37:37] Reset: 2.87375s, 12000 calls @ 2873752us
#
# [16:37:37] UpdatePosition: 3.97967s, 30459 calls @ 3979666us
#
# [16:37:37] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 3/3] END colsample_bytree=1.0, gamma=5, max_depth=3, min_child_weight=10, subsample=0.8;, score=0.256 total time= 2.9min
# [16:37:56] ======== Monitor (0): HostSketchContainer ========
# [16:37:56] AllReduce: 0.044073s, 1 calls @ 44073us
#
# [16:37:56] MakeCuts: 0.045801s, 1 calls @ 45801us
#
# [16:37:56] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:37:56] ======== Monitor (0):  ========
# [16:37:56] InitCompressedData: 0.057632s, 1 calls @ 57632us
#
# [16:40:20] ======== Monitor (0): Learner ========
# [16:40:20] Configure: 0.001688s, 1 calls @ 1688us
#
# [16:40:20] EvalOneIter: 0.004757s, 600 calls @ 4757us
#
# [16:40:20] GetGradient: 0.894709s, 600 calls @ 894709us
#
# [16:40:20] PredictRaw: 0.004627s, 600 calls @ 4627us
#
# [16:40:20] UpdateOneIter: 143.031s, 600 calls @ 143031214us
#
# [16:40:20] ======== Monitor (0): GBTree ========
# [16:40:20] BoostNewTrees: 142.12s, 600 calls @ 142120032us
#
# [16:40:20] CommitModel: 0.000532s, 600 calls @ 532us
#
# [16:40:20] ======== Device 0 Memory Allocations:  ========
# [16:40:20] Peak memory usage: 4410MiB
# [16:40:20] Number of allocations: 4293311
# [16:40:20] ======== Monitor (0): updater_gpu_hist ========
# [16:40:20] InitData: 0.114593s, 12000 calls @ 114593us
#
# [16:40:20] InitDataOnce: 0.113635s, 1 calls @ 113635us
#
# [16:40:20] Update: 139.303s, 12000 calls @ 139303427us
#
# [16:40:20] UpdatePredictionCache: 2.23971s, 12000 calls @ 2239709us
#
# [16:40:20] ======== Monitor (0): gradient_based_sampler ========
# [16:40:20] Sample: 0.636726s, 12000 calls @ 636726us
#
# [16:40:20] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:40:20] AllReduce: 0.005761s, 33389 calls @ 5761us
#
# [16:40:20] BuildHist: 0.397861s, 31825 calls @ 397861us
#
# [16:40:20] EvaluateSplits: 46.679s, 31825 calls @ 46679003us
#
# [16:40:20] FinalisePosition: 0.54732s, 12000 calls @ 547320us
#
# [16:40:20] InitRoot: 84.3672s, 12000 calls @ 84367214us
#
# [16:40:20] Reset: 3.02053s, 12000 calls @ 3020533us
#
# [16:40:20] UpdatePosition: 4.02951s, 31825 calls @ 4029507us
#
# [16:40:20] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 1/3] END colsample_bytree=0.6, gamma=1, max_depth=3, min_child_weight=10, subsample=0.6;, score=0.256 total time= 2.8min
# [16:40:41] ======== Monitor (0): HostSketchContainer ========
# [16:40:41] AllReduce: 0.041635s, 1 calls @ 41635us
#
# [16:40:41] MakeCuts: 0.042985s, 1 calls @ 42985us
#
# [16:40:41] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:40:41] ======== Monitor (0):  ========
# [16:40:41] InitCompressedData: 0.058309s, 1 calls @ 58309us
#
# [16:43:15] ======== Monitor (0): Learner ========
# [16:43:15] Configure: 0.001583s, 1 calls @ 1583us
#
# [16:43:15] EvalOneIter: 0.005478s, 600 calls @ 5478us
#
# [16:43:15] GetGradient: 0.960607s, 600 calls @ 960607us
#
# [16:43:15] PredictRaw: 0.004976s, 600 calls @ 4976us
#
# [16:43:15] UpdateOneIter: 152.693s, 600 calls @ 152693046us
#
# [16:43:15] ======== Monitor (0): GBTree ========
# [16:43:15] BoostNewTrees: 151.713s, 600 calls @ 151713259us
#
# [16:43:15] CommitModel: 0.000547s, 600 calls @ 547us
#
# [16:43:15] ======== Device 0 Memory Allocations:  ========
# [16:43:15] Peak memory usage: 4753MiB
# [16:43:15] Number of allocations: 4655765
# [16:43:15] ======== Monitor (0): updater_gpu_hist ========
# [16:43:15] InitData: 0.276641s, 12000 calls @ 276641us
#
# [16:43:15] InitDataOnce: 0.275621s, 1 calls @ 275621us
#
# [16:43:15] Update: 148.69s, 12000 calls @ 148690478us
#
# [16:43:15] UpdatePredictionCache: 2.36562s, 12000 calls @ 2365621us
#
# [16:43:15] ======== Monitor (0): gradient_based_sampler ========
# [16:43:15] Sample: 0.665589s, 12000 calls @ 665589us
#
# [16:43:15] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:43:15] AllReduce: 0.006737s, 33380 calls @ 6737us
#
# [16:43:15] BuildHist: 0.430965s, 31822 calls @ 430965us
#
# [16:43:15] EvaluateSplits: 49.3706s, 31822 calls @ 49370562us
#
# [16:43:15] FinalisePosition: 0.620569s, 12000 calls @ 620569us
#
# [16:43:15] InitRoot: 90.2772s, 12000 calls @ 90277183us
#
# [16:43:15] Reset: 3.23156s, 12000 calls @ 3231562us
#
# [16:43:15] UpdatePosition: 4.29925s, 31822 calls @ 4299248us
#
# [16:43:15] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 2/3] END colsample_bytree=0.6, gamma=1, max_depth=3, min_child_weight=10, subsample=0.6;, score=0.256 total time= 2.9min
# [16:43:37] ======== Monitor (0): HostSketchContainer ========
# [16:43:37] AllReduce: 0.041443s, 1 calls @ 41443us
#
# [16:43:37] MakeCuts: 0.042804s, 1 calls @ 42804us
#
# [16:43:38] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:43:38] ======== Monitor (0):  ========
# [16:43:38] InitCompressedData: 0.049467s, 1 calls @ 49467us
#
# [16:46:16] ======== Monitor (0): Learner ========
# [16:46:16] Configure: 0.000795s, 1 calls @ 795us
#
# [16:46:16] EvalOneIter: 0.005855s, 600 calls @ 5855us
#
# [16:46:16] GetGradient: 0.982676s, 600 calls @ 982676us
#
# [16:46:16] PredictRaw: 0.006153s, 600 calls @ 6153us
#
# [16:46:16] UpdateOneIter: 157.852s, 600 calls @ 157851621us
#
# [16:46:16] ======== Monitor (0): GBTree ========
# [16:46:16] BoostNewTrees: 156.849s, 600 calls @ 156848673us
#
# [16:46:16] CommitModel: 0.000746s, 600 calls @ 746us
#
# [16:46:16] ======== Device 0 Memory Allocations:  ========
# [16:46:16] Peak memory usage: 5095MiB
# [16:46:16] Number of allocations: 5017359
# [16:46:16] ======== Monitor (0): updater_gpu_hist ========
# [16:46:16] InitData: 0.186528s, 12000 calls @ 186528us
#
# [16:46:16] InitDataOnce: 0.185503s, 1 calls @ 185503us
#
# [16:46:16] Update: 153.721s, 12000 calls @ 153720636us
#
# [16:46:16] UpdatePredictionCache: 2.43571s, 12000 calls @ 2435712us
#
# [16:46:16] ======== Monitor (0): gradient_based_sampler ========
# [16:46:16] Sample: 0.672816s, 12000 calls @ 672816us
#
# [16:46:16] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:46:16] AllReduce: 0.006604s, 33279 calls @ 6604us
#
# [16:46:16] BuildHist: 0.430442s, 31655 calls @ 430442us
#
# [16:46:16] EvaluateSplits: 50.9154s, 31655 calls @ 50915372us
#
# [16:46:16] FinalisePosition: 0.637105s, 12000 calls @ 637105us
#
# [16:46:16] InitRoot: 93.6765s, 12000 calls @ 93676486us
#
# [16:46:16] Reset: 3.31877s, 12000 calls @ 3318770us
#
# [16:46:16] UpdatePosition: 4.37278s, 31655 calls @ 4372779us
#
# [16:46:17] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 3/3] END colsample_bytree=0.6, gamma=1, max_depth=3, min_child_weight=10, subsample=0.6;, score=0.256 total time= 3.0min
# [16:46:40] ======== Monitor (0): HostSketchContainer ========
# [16:46:40] AllReduce: 0.041597s, 1 calls @ 41597us
#
# [16:46:40] MakeCuts: 0.042922s, 1 calls @ 42922us
#
# [16:46:40] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:46:40] ======== Monitor (0):  ========
# [16:46:40] InitCompressedData: 0.042327s, 1 calls @ 42327us
#
# [16:49:39] ======== Monitor (0): Learner ========
# [16:49:39] Configure: 0.000911s, 1 calls @ 911us
#
# [16:49:39] EvalOneIter: 0.005618s, 600 calls @ 5618us
#
# [16:49:39] GetGradient: 0.94066s, 600 calls @ 940660us
#
# [16:49:39] PredictRaw: 0.006686s, 600 calls @ 6686us
#
# [16:49:39] UpdateOneIter: 178.313s, 600 calls @ 178313148us
#
# [16:49:39] ======== Monitor (0): GBTree ========
# [16:49:39] BoostNewTrees: 177.351s, 600 calls @ 177350880us
#
# [16:49:39] CommitModel: 0.000607s, 600 calls @ 607us
#
# [16:49:39] ======== Device 0 Memory Allocations:  ========
# [16:49:39] Peak memory usage: 5438MiB
# [16:49:39] Number of allocations: 5463247
# [16:49:39] ======== Monitor (0): updater_gpu_hist ========
# [16:49:39] InitData: 0.151014s, 12000 calls @ 151014us
#
# [16:49:39] InitDataOnce: 0.149952s, 1 calls @ 149952us
#
# [16:49:39] Update: 174.293s, 12000 calls @ 174293019us
#
# [16:49:39] UpdatePredictionCache: 2.3274s, 12000 calls @ 2327400us
#
# [16:49:39] ======== Monitor (0): gradient_based_sampler ========
# [16:49:39] Sample: 0.663293s, 12000 calls @ 663293us
#
# [16:49:39] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:49:39] AllReduce: 0.008819s, 43811 calls @ 8819us
#
# [16:49:39] BuildHist: 0.83967s, 42032 calls @ 839670us
#
# [16:49:39] EvaluateSplits: 70.5513s, 42032 calls @ 70551268us
#
# [16:49:39] FinalisePosition: 0.631082s, 12000 calls @ 631082us
#
# [16:49:39] InitRoot: 92.1177s, 12000 calls @ 92117695us
#
# [16:49:39] Reset: 3.26429s, 12000 calls @ 3264288us
#
# [16:49:39] UpdatePosition: 6.47413s, 42032 calls @ 6474126us
#
# [16:49:39] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 1/3] END colsample_bytree=0.6, gamma=1, max_depth=4, min_child_weight=10, subsample=0.6;, score=0.259 total time= 3.5min
# [16:50:09] ======== Monitor (0): HostSketchContainer ========
# [16:50:09] AllReduce: 0.050814s, 1 calls @ 50814us
#
# [16:50:09] MakeCuts: 0.052048s, 1 calls @ 52048us
#
# [16:50:09] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:50:10] ======== Monitor (0):  ========
# [16:50:10] InitCompressedData: 0.050738s, 1 calls @ 50738us
#
# [16:53:12] ======== Monitor (0): Learner ========
# [16:53:12] Configure: 0.000987s, 1 calls @ 987us
#
# [16:53:12] EvalOneIter: 0.006022s, 600 calls @ 6022us
#
# [16:53:12] GetGradient: 0.973509s, 600 calls @ 973509us
#
# [16:53:12] PredictRaw: 0.004752s, 600 calls @ 4752us
#
# [16:53:12] UpdateOneIter: 181.913s, 600 calls @ 181912894us
#
# [16:53:12] ======== Monitor (0): GBTree ========
# [16:53:12] BoostNewTrees: 180.92s, 600 calls @ 180920101us
#
# [16:53:12] CommitModel: 0.000751s, 600 calls @ 751us
#
# [16:53:12] ======== Device 0 Memory Allocations:  ========
# [16:53:12] Peak memory usage: 5780MiB
# [16:53:12] Number of allocations: 5909188
# [16:53:12] ======== Monitor (0): updater_gpu_hist ========
# [16:53:12] InitData: 0.169728s, 12000 calls @ 169728us
#
# [16:53:12] InitDataOnce: 0.168658s, 1 calls @ 168658us
#
# [16:53:12] Update: 177.851s, 12000 calls @ 177850987us
#
# [16:53:12] UpdatePredictionCache: 2.38565s, 12000 calls @ 2385647us
#
# [16:53:12] ======== Monitor (0): gradient_based_sampler ========
# [16:53:12] Sample: 0.671794s, 12000 calls @ 671794us
#
# [16:53:12] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:53:12] AllReduce: 0.008583s, 43816 calls @ 8583us
#
# [16:53:12] BuildHist: 0.836655s, 42049 calls @ 836655us
#
# [16:53:12] EvaluateSplits: 72.1223s, 42049 calls @ 72122269us
#
# [16:53:12] FinalisePosition: 0.638227s, 12000 calls @ 638227us
#
# [16:53:12] InitRoot: 93.9568s, 12000 calls @ 93956795us
#
# [16:53:12] Reset: 3.29696s, 12000 calls @ 3296962us
#
# [16:53:12] UpdatePosition: 6.56672s, 42049 calls @ 6566716us
#
# [16:53:12] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 2/3] END colsample_bytree=0.6, gamma=1, max_depth=4, min_child_weight=10, subsample=0.6;, score=0.259 total time= 3.5min
# [16:53:42] ======== Monitor (0): HostSketchContainer ========
# [16:53:42] AllReduce: 0.050151s, 1 calls @ 50151us
#
# [16:53:42] MakeCuts: 0.051745s, 1 calls @ 51745us
#
# [16:53:42] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:53:43] ======== Monitor (0):  ========
# [16:53:43] InitCompressedData: 0.055954s, 1 calls @ 55954us
#
# [16:56:33] ======== Monitor (0): Learner ========
# [16:56:33] Configure: 0.000957s, 1 calls @ 957us
#
# [16:56:33] EvalOneIter: 0.005033s, 600 calls @ 5033us
#
# [16:56:33] GetGradient: 0.919706s, 600 calls @ 919706us
#
# [16:56:33] PredictRaw: 0.005247s, 600 calls @ 5247us
#
# [16:56:33] UpdateOneIter: 169.509s, 600 calls @ 169509005us
#
# [16:56:33] ======== Monitor (0): GBTree ========
# [16:56:33] BoostNewTrees: 168.572s, 600 calls @ 168571913us
#
# [16:56:33] CommitModel: 0.000579s, 600 calls @ 579us
#
# [16:56:33] ======== Device 0 Memory Allocations:  ========
# [16:56:33] Peak memory usage: 6123MiB
# [16:56:33] Number of allocations: 6353650
# [16:56:33] ======== Monitor (0): updater_gpu_hist ========
# [16:56:33] InitData: 0.156073s, 12000 calls @ 156073us
#
# [16:56:33] InitDataOnce: 0.155057s, 1 calls @ 155057us
#
# [16:56:33] Update: 165.726s, 12000 calls @ 165725817us
#
# [16:56:33] UpdatePredictionCache: 2.23456s, 12000 calls @ 2234563us
#
# [16:56:33] ======== Monitor (0): gradient_based_sampler ========
# [16:56:33] Sample: 0.648714s, 12000 calls @ 648714us
#
# [16:56:33] ======== Monitor (0): GPUHistMakerDevice0 ========
# [16:56:33] AllReduce: 0.008086s, 43638 calls @ 8086us
#
# [16:56:33] BuildHist: 0.803606s, 41788 calls @ 803606us
#
# [16:56:33] EvaluateSplits: 67.2911s, 41788 calls @ 67291078us
#
# [16:56:33] FinalisePosition: 0.582148s, 12000 calls @ 582148us
#
# [16:56:33] InitRoot: 87.4079s, 12000 calls @ 87407866us
#
# [16:56:33] Reset: 3.10176s, 12000 calls @ 3101760us
#
# [16:56:33] UpdatePosition: 6.14742s, 41788 calls @ 6147423us
#
# [16:56:33] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [CV 3/3] END colsample_bytree=0.6, gamma=1, max_depth=4, min_child_weight=10, subsample=0.6;, score=0.259 total time= 3.3min
# [16:57:01] ======== Monitor (0): HostSketchContainer ========
# [16:57:01] AllReduce: 0.060013s, 1 calls @ 60013us
#
# [16:57:01] MakeCuts: 0.06111s, 1 calls @ 61110us
#
# [16:57:02] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# [16:57:02] ======== Monitor (0):  ========
# [16:57:02] InitCompressedData: 0.085675s, 1 calls @ 85675us
#
# [17:01:23] ======== Monitor (0): Learner ========
# [17:01:23] Configure: 0.00099s, 1 calls @ 990us
#
# [17:01:23] EvalOneIter: 0.006432s, 600 calls @ 6432us
#
# [17:01:23] GetGradient: 1.47516s, 600 calls @ 1475160us
#
# [17:01:23] PredictRaw: 0.006181s, 600 calls @ 6181us
#
# [17:01:23] UpdateOneIter: 260.424s, 600 calls @ 260423534us
#
# [17:01:23] ======== Monitor (0): GBTree ========
# [17:01:23] BoostNewTrees: 258.926s, 600 calls @ 258926151us
#
# [17:01:23] CommitModel: 0.000908s, 600 calls @ 908us
#
# [17:01:23] ======== Device 0 Memory Allocations:  ========
# [17:01:23] Peak memory usage: 6745MiB
# [17:01:23] Number of allocations: 6801278
# [17:01:23] ======== Monitor (0): updater_gpu_hist ========
# [17:01:23] InitData: 0.23417s, 12000 calls @ 234170us
#
# [17:01:23] InitDataOnce: 0.233103s, 1 calls @ 233103us
#
# [17:01:23] Update: 255.027s, 12000 calls @ 255026762us
#
# [17:01:23] UpdatePredictionCache: 3.14829s, 12000 calls @ 3148288us
#
# [17:01:23] ======== Monitor (0): gradient_based_sampler ========
# [17:01:23] Sample: 0.964894s, 12000 calls @ 964894us
#
# [17:01:23] ======== Monitor (0): GPUHistMakerDevice0 ========
# [17:01:23] AllReduce: 0.010109s, 44029 calls @ 10109us
#
# [17:01:23] BuildHist: 0.891858s, 42477 calls @ 891858us
#
# [17:01:23] EvaluateSplits: 102.662s, 42477 calls @ 102662404us
#
# [17:01:23] FinalisePosition: 0.691801s, 12000 calls @ 691801us
#
# [17:01:23] InitRoot: 138.479s, 12000 calls @ 138479088us
#
# [17:01:23] Reset: 3.95301s, 12000 calls @ 3953014us
#
# [17:01:23] UpdatePosition: 7.79004s, 42477 calls @ 7790040us
# RandomizedSearchCV(cv=<generator object _BaseKFold.split at 0x00000192416D1200>,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, gpu_id=None,
#                                            grow_policy=None,
#                                            importance_...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            n_estimators=600, n_jobs=None,
#                                            nthread=1, num_parallel_tree=None,
#                                            objective='multi:softmax', ...),
#                    n_iter=5, n_jobs=1,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'max_depth': [3, 4, 5],
#                                         'min_child_weight': [1, 5, 10],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=42, scoring='accuracy', verbose=3)

# %%
#best parameters
random_search.best_params_
# Out:
# {'subsample': 0.8,
#  'min_child_weight': 10,
#  'max_depth': 4,
#  'gamma': 1.5,
#  'colsample_bytree': 0.6}

# %%
#test accuracy
accuracy_score(df_views.iloc[test_idx], random_search.predict(data.iloc[test_idx]))
# Out:
# [17:02:38] DEBUG: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\tree\updater_gpu_hist.cu:755: [GPU Hist]: Configure
# 0.2599

# %% [markdown]
# Setup training for the Neural Network. We will try 3 different sets of hyper-parameters.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

# %%
data

# %%
# torch.cuda.empty_cache()

# %%
# Get features in tensor form for neural network (ensure we only use training data here) => Also push to cuda

lyrics = torch.tensor(df_lyrics.loc[train_idx].values).type('torch.FloatTensor').to(device)
titles = torch.tensor(df_titles.loc[train_idx].values).type('torch.FloatTensor').to(device)
artists = torch.tensor(df_artists.loc[train_idx].values).unsqueeze(1).type('torch.FloatTensor').to(device)
age = torch.tensor(df_age.loc[train_idx].values).unsqueeze(1).type('torch.FloatTensor').to(device)
tags = torch.tensor(df_tags.loc[train_idx].values).type('torch.FloatTensor').to(device)
views = torch.tensor(df_views.loc[train_idx].values).type('torch.FloatTensor').to(device)

# %%
print(lyrics.shape[1] + titles.shape[1] + 1 + 1 + tags.shape[1])

# %%
# del lyrics, titles, artists, age, tags, views
# del model1

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# Define the neural network architectures
class SongViewCountPredictor1(nn.Module):
    def __init__(self, input_size):
        super(SongViewCountPredictor1, self).__init__()
        self.fc1 = nn.Linear(input_size, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4 = nn.Linear(256, 20)
        self.relu = nn.ReLU()
        self.sig = nn.Sigmoid()
        self.soft = nn.Softmax()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Define a custom dataset
class SongDataset(Dataset):
    def __init__(self, lyrics, titles, artists, age, tags, views):
        self.lyrics = lyrics
        self.titles = titles
        self.artists = artists
        self.age = age
        self.tags = tags
        self.views = views

    def __len__(self):
        return len(self.views)

    def __getitem__(self, index):
        lyrics = self.lyrics[index]
        titles = self.titles[index]
        artists = self.artists[index]
        age = self.age[index]
        tags = self.tags[index]
        views = self.views[index]
        return lyrics, titles, artists, age, tags, views

# Set random seed for reproducibility
torch.manual_seed(42)

# dataset = SongDataset(lyrics, titles, artists, age, tags, views)
# dataloader = DataLoader(dataset, batch_size=2048, shuffle=True)

# Define the model and optimizer (push models to GPU)
input_size = lyrics.shape[1] + titles.shape[1] + 1 + 1 + tags.shape[1] # (artists and age are size 1)
# model1 = SongViewCountPredictor1(input_size).to(device)
# model1 = torch.Sequential(
#     nn.Linear(input_size, 1024),
#     nn.ReLU(),
#     nn.Linear(1024, 512),
#     nn.ReLU(),
#     nn.Dropout(0.2),
#     nn.Linear(512, 256),
#     nn.ReLU(),
#     nn.Linear(256, 20),
#     optim.Adam(model1.parameters(), lr=0.0001),
# ).to(device)
# model2 = SongViewCountPredictor2(input_size).to(device)
#model3 = SongViewCountPredictor3(input_size).to(device)
# optimizer1 = optim.Adam(model1.parameters(), lr=0.0001)
# optimizer2 = optim.SGD(model2.parameters(), lr=0.0025)
#optimizer3 = optim.Adam(model3.parameters(), lr=0.0025)
# criterion = nn.CrossEntropyLoss() # using MSE as lossbb

# %%
# #create torch sequential model with dropout
# model1 = torch.nn.Sequential(
#     nn.LSTM(input_size, 1024),
#     nn.ReLU(),
#     nn.LSTM(1024, 512),
#     nn.ReLU(),
#     nn.Dropout(0.2),
#     nn.LSTM(512, 256),
#     nn.ReLU(),
#     nn.LSTM(256, 20),
#     # nn.Softmax(dim=1) 
# ).to(device)

# optimizer1 = optim.Adam(model1.parameters())
# # optimizer2 = optim.SGD(model2.parameters(), lr=0.0025)
# #optimizer3 = optim.Adam(model3.parameters(), lr=0.0025)
# criterion = nn.CrossEntropyLoss() # using MSE as lossbb

# %%
dataset = SongDataset(lyrics, titles, artists, age, tags, views)
dataloader = DataLoader(dataset, batch_size=(128), shuffle=True)

# %%
from keras import layers as layers
from keras import models as models
from keras import optimizers as optimizers
from keras import losses as losses
from keras import metrics as metrics
import tensorflow as tf

# %%
#printing tensorflow version
print(tf.__version__)

# %%
gpus = tf.config.list_physical_devices('GPU')
print(gpus)
if gpus:
  # Restrict TensorFlow to only use the first GPU
  try:
    tf.config.set_visible_devices(gpus[0], 'GPU')
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
  except RuntimeError as e:
    # Visible devices must be set before GPUs have been initialized
    print(e)

# %%
input_size

# %%
model = models.Sequential()
model.add(layers.LSTM(1024, activation='relu', input_shape=(input_size,1)))
model.add(layers.LSTM(512, activation='relu'))
model.add(layers.Dropout(0.2))
model.add(layers.LSTM(256, activation='relu'))
model.add(layers.Dense(20, activation='softmax'))

model.compile(optimizer=optimizers.Adam(lr=0.0001), loss = losses.categorical_crossentropy, metrics=['accuracy'])

# %%
# Training loop
num_epochs = 50
for epoch in range(num_epochs):
    epoch_loss1 = 0.0
    epoch_loss2 = 0.0
    epoch_loss3 = 0.0
    for lyrics, titles, artists, age, tags, views in dataloader:
        # move batch data to GPU
        # lyrics = lyrics.to(device)
        # titles = titles.to(device)
        # artists = artists.to(device)
        # age = age.to(device)
        # tags = tags.to(device)
        # views = views.to(device)
        # Forward pass
        inputs = torch.cat((lyrics, titles, artists, age, tags), dim=1)
        outputs1 = model1(inputs)
        
        # Compute loss
        loss1 = criterion(outputs1, torch.argmax(views, dim=1))

        # Backward pass and optimization
        optimizer1.zero_grad()
        loss1.backward()
        optimizer1.step()
        
        epoch_loss1 += loss1.item()

    print(f"Epoch [{epoch+1}/{num_epochs}]:\n Loss1: {epoch_loss1/len(dataloader):.4f}") #\n Loss2: {epoch_loss2/len(dataloader):.4f} \n Loss3: {epoch_loss3/len(dataloader):.4f}\n")

# %%
print(outputs1.shape)

# %%
# Transform testing data into tensors (ensure we're only locating testing data)

lyrics = torch.tensor(df_lyrics.loc[test_idx].values).type('torch.FloatTensor').to(device)
titles = torch.tensor(df_titles.loc[test_idx].values).type('torch.FloatTensor').to(device)
artists = torch.tensor(df_artists.loc[test_idx].values).unsqueeze(1).type('torch.FloatTensor').to(device)
age = torch.tensor(df_age.loc[test_idx].values).unsqueeze(1).type('torch.FloatTensor').to(device)
tags = torch.tensor(df_tags.loc[test_idx].values).type('torch.FloatTensor').to(device)
views = torch.tensor(df_views.loc[test_idx].values).type('torch.FloatTensor').to(device)

# %%
# Testing loop
# Set the model to evaluation mode - important for batch normalization and dropout layers
model1.eval()
#model2.eval()
#model3.eval()

dataset_test = SongDataset(lyrics, titles, artists, age, tags, views)
dataloader_test = DataLoader(dataset_test, batch_size=32, shuffle=True)

size = len(dataloader_test.dataset)
num_batches = len(dataloader_test)

test_loss1, correct1 = 0, 0
test_loss2, correct2 = 0, 0
test_loss3, correct3 = 0, 0

loss_fn = nn.CrossEntropyLoss()

# Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
# also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
with torch.no_grad():
    for lyrics, titles, artists, age, tags, views in dataloader_test:
#         print(1)
        # move batch data to GPU
        lyrics = lyrics.to(device)
        titles = titles.to(device)
        artists = artists.to(device)
        age = age.to(device)
        tags = tags.to(device)
        views = views.to(device)
        
        # predict the views count
        X = torch.cat((lyrics, titles, artists, age, tags), dim=1)
        pred1 = model1(X)
#         pred2 = model2(X)
        #pred3 = model3(X)
        
        y = views
        test_loss1 += loss_fn(pred1, torch.argmax(y, dim = 1)).item()
#         print(torch.argmax(pred1, dim=1), "|||" , torch.argmax(y, dim=1))
        correct1 += (torch.argmax(nn.functional.softmax(pred1), dim=1) == torch.argmax(y, dim =1)).type(torch.float).sum().item()
        
#         test_loss2 += loss_fn(pred2, y).item()
#         correct2 += (torch.argmax(pred2, dim=1) == torch.argmax(y, dim =1)).type(torch.float).sum().item()        #
        #test_loss3 += loss_fn(pred3, y).item()
        #correct3 += (pred3.argmax(1) == y).type(torch.float).sum().item()

test_loss1 /= num_batches
correct1 /= size

# test_loss2 /= num_batches
# correct2 /= size
#
#test_loss3 /= num_batches
#correct3 /= size

print(f"Test Error 1: \n Accuracy: {(100*correct1):>0.1f}%, Avg loss: {test_loss1:>8f} \n Test Error 2: \n Accuracy: {(100*correct2):>0.1f}%, Avg loss: {test_loss2:>8f} \n Test Error 3: \n Accuracy: {(100*correct3):>0.1f}%, Avg loss: {test_loss3:>8f} \n")

# %%
d1 = torch.cat((lyrics, titles, artists, age, tags), dim=1)[100]

# %%
model1(d1)

# %%
nn.functional.softmax(model1(d1))

# %%
print(torch.argmax(views[120]), views[120])

# %%
print(views[120].argmax())

# %%
np.argmax(views[120].cpu().numpy())

# %%
torch.argmax(model1(d1))

# %%
# This cell for testing trained model manually

# %% [markdown]
# Now we train and test our KNN. We will use a RandomizedSearch to find the right hyperparams for this type of algorithm.

# %%
# Create a k-fold cross-validator
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

data_train = data.loc[train_idx]
X = data_train.drop(columns=['encoded_views'])
y = data_train['encoded_views']

parameters = {"n_neighbors": list(range(1, 30))}
    
model = KNeighborsClassifier()
random_search = RandomizedSearchCV(model, parameters, scoring="neg_mean_squared_error", cv=kfold, n_jobs=-1, verbose=100)
print(f"Fitting KNeighborsClassifer...")
random_search.fit(X, y)
print('\nKNN Regression Best Params: ', random_search.best_params_)

# %%
# Testing KNN
model = KNeighborsClassifier(n_neighbors=random_search.best_params_['n_neighbors'])
model.fit(X,y)

data_test = data.loc[test_idx]
X_test = data_test.drop(columns=['encoded_views'])
y_test = data_test['encoded_views']

y_test_hat = model.predict(X_test) 

test_accuracy = accuracy_score(y_test, y_test_hat) * 100

print("Accuracy for our testing dataset with tuning is : {:.2f}%".format(test_accuracy))
